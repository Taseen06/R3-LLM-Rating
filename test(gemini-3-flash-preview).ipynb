# %%
import pandas as pd
import PIL
from PIL import Image

from tqdm import tqdm
for i in tqdm(range(10)):
    pass
# Out:
# 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 49636.73it/s]

# %%
import os
print(os.path.exists("./rico_dataset"))
# Out:
# True

# %%
with open('LLM_PIPELINE_(gemini-3-flash-preview).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# --- Starting Dual Pipeline with gemini-3-flash-preview ---
#   0%|                                      | 23/15000 [00:46<8:21:47,  2.01s/it]
# Interrupted. Saving current progress...
# Success. Files saved.
