# %%
import pandas as pd
import PIL
from PIL import Image

from tqdm import tqdm
for i in tqdm(range(10)):
    pass
# Out:
# 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 45051.60it/s]

# %%
import os
print(os.path.exists("./rico_dataset"))
# Out:
# True

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Now run your script
with open('LLM_PIPELINE_(gemini-3-flash-preview).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# [TEST] Verifying API with first screen...
# [RETRY JSON] 52214 attempt 1/3: ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please
# [RETRY JSON] 52214 attempt 2/3: ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please
# [ERROR JSON] 52214: quota exhausted after retries
# [TEST] Results: JPEG=1, JSON=0
# ✅ API TEST PASSED - Proceeding with full processing
#
# Processing 14999 screens...
# Resume state: JPEG=3, JSON=1, complete=1
# Batch 1:   0%|                                            | 0/5 [00:00<?, ?it/s]
# [RETRY JPEG] 17476 attempt 1/3: ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please
# [RETRY JPEG] 26390 attempt 1/3: ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please
# ...
