# %%
import pandas as pd
import PIL
from PIL import Image

from tqdm import tqdm
for i in tqdm(range(10)):
    pass
# Out:
# 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 39869.81it/s]

# %%
import os
print(os.path.exists("./rico_dataset"))
# Out:
# True

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  12%|███▉                             | 1801/15000 [2:32:15<18:35:48,  5.07s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 1802...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#   8%|██▋                              | 1059/13198 [1:33:58<17:57:18,  5.32s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 2862...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  10%|███▏                             | 1154/12138 [1:33:26<14:49:27,  4.86s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 4017...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  10%|███▎                             | 1084/10983 [1:33:17<14:11:53,  5.16s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 5102...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#   7%|██▎                                | 660/9898 [1:15:19<17:34:24,  6.85s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 5763...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  12%|████                              | 1090/9237 [1:50:41<13:47:23,  6.09s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 6854...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  22%|███████▋                           | 1788/8146 [2:36:59<9:18:13,  5.27s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 8643...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  11%|████                                  | 676/6357 [56:48<7:49:55,  4.96s/it]

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 9320...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  19%|██████▋                            | 1077/5680 [1:34:43<6:44:51,  5.28s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 10398...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  24%|████████▎                          | 1092/4602 [1:24:17<4:30:56,  4.63s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 11481...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  30%|██████████▌                        | 1063/3519 [1:34:46<3:38:57,  5.35s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 12545...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  40%|██████████████▌                     | 994/2455 [1:16:39<2:04:08,  5.10s/it]

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 13625...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
#  67%|█████████████████████████▍            | 922/1375 [1:12:52<35:48,  4.74s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 14545...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
# 100%|█████████████████████████████████████████| 455/455 [39:20<00:00,  5.19s/it]
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 15000...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
# 0it [00:00, ?it/s]
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(qwen3-vl).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 15000...
# --- Starting Dual Pipeline with qwen3-vl:235b-instruct-cloud ---
# 0it [00:00, ?it/s]
# Success. Files saved.
