# %%
import pandas as pd
import PIL
from PIL import Image

from tqdm import tqdm
for i in tqdm(range(10)):
    pass
# Out:
# 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 90785.80it/s]

# %%
import os
print(os.path.exists("./rico_dataset"))
# Out:
# True

# %%
with open('LLM_PIPELINE_(gemma3).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# --- Starting Dual Pipeline with gemma3:27b-cloud ---
#   0%|                                     | 24/15000 [01:44<17:28:26,  4.20s/it]

# %%
with open('LLM_PIPELINE_(gemma3).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 9100...
# --- Starting Dual Pipeline with gemma3:27b-cloud ---
#  30%|██████████▎                        | 1743/5900 [2:07:09<5:03:15,  4.38s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(gemma3).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 10824...
# --- Starting Dual Pipeline with gemma3:27b-cloud ---
# 100%|█████████████████████████████████████| 4176/4176 [5:32:45<00:00,  4.78s/it]
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(gemma3).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 15000...
# --- Starting Dual Pipeline with gemma3:27b-cloud ---
# 0it [00:00, ?it/s]
# Success. Files saved.
