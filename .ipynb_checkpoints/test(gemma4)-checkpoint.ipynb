# %%
import pandas as pd
import PIL
from PIL import Image

from tqdm import tqdm
for i in tqdm(range(10)):
    pass
# Out:
# 100%|████████████████████████████████████████| 10/10 [00:00<00:00, 60699.04it/s]

# %%
import os
print(os.path.exists("./rico_dataset"))
# Out:
# True

# %%
with open('LLM_PIPELINE_(gemma4).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# --- Starting Dual Pipeline with gemma4:31b-cloud ---
#  27%|████████▌                       | 4019/15000 [13:46:35<37:38:28, 12.34s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(gemma4).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 4015...
# --- Starting Dual Pipeline with gemma4:31b-cloud ---
#  39%|████████████▉                    | 4323/10985 [9:33:56<14:44:28,  7.97s/it]
# Interrupted. Saving current progress...
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(gemma4).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 8364...
# --- Starting Dual Pipeline with gemma4:31b-cloud ---
# 100%|████████████████████████████████████| 6636/6636 [20:22:18<00:00, 11.05s/it]
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(gemma4).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 15000...
# --- Starting Dual Pipeline with gemma4:31b-cloud ---
# 0it [00:00, ?it/s]
# Success. Files saved.

# %%
with open('LLM_PIPELINE_(gemma4).py', encoding='utf-8') as f:
    exec(f.read())
# Out:
# Resuming from screen 15000...
# --- Starting Dual Pipeline with gemma4:31b-cloud ---
# 0it [00:00, ?it/s]
# Success. Files saved.
